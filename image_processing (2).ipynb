# %%
#Implement Classifier Using Algorithmic approach.
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
train_path = "/content/drive/MyDrive/PetImages"
DATADIR = train_path
CATEGORIES = ["Cat", "Dog"]

# %%
from tqdm import tqdm

# %%
histo = []
label = []
for i in CATEGORIES:
  path = os.path.join(train_path,i)
  class_num = CATEGORIES.index(i)
  for j in tqdm(os.listdir(path)):
    try:
      img = cv2.imread(os.path.join(path,j))
      color = ('b','g','r')
      for i,col in enumerate(color):
        feature = cv2.calcHist([img],[i],None,[256],[0,256])
    #img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    #feature = cv2.calcHist([img], [0], None, [256], [0, 256])
        feature = cv2.normalize(feature,feature)
        feature = feature.flatten()
        histo.append(feature)
        label.append(class_num)
    except Exception as e:
      pass
# Out:
# ...
# 100%|██████████| 12501/12501 [01:21<00:00, 153.39it/s]
#
# ...
#  16%|█▌        | 1952/12501 [00:13<01:11, 147.67it/s]
# ...
# ...
# 100%|██████████| 12501/12501 [01:28<00:00, 140.75it/s]

# %%
histo[2]
# Out:
# array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        2.02139185e-04, 6.87273219e-04, 1.73839694e-03, 4.97262366e-03,
#        1.22496346e-02, 1.86776612e-02, 2.52673980e-02, 4.70580012e-02,
#        5.53457066e-02, 7.09912777e-02, 7.83087164e-02, 8.81326795e-02,
#        8.93050879e-02, 9.43585709e-02, 9.35904384e-02, 9.69459489e-02,
#        1.04222961e-01, 1.12025537e-01, 1.00907877e-01, 9.09222066e-02,
#        7.75001645e-02, 6.87677488e-02, 6.52505308e-02, 6.12077452e-02,
# ...

# %%
X = np.array(histo)
y = np.array(label)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report
cluster = [3,4]
for i in cluster:
    print("The result of cluster = ", i, "is: ")
    model = KNeighborsClassifier(n_neighbors=i)
    model.fit(X_train,y_train)
    pred = model.predict(X_test)
    print(classification_report( y_test,pred))
# Out:
# The result of cluster =  3 is:
#               precision    recall  f1-score   support
#
#            0       0.61      0.49      0.54      7428
#            1       0.58      0.69      0.63      7551
#
#     accuracy                           0.59     14979
#    macro avg       0.59      0.59      0.59     14979
# weighted avg       0.59      0.59      0.59     14979
#
# The result of cluster =  4 is:
#               precision    recall  f1-score   support
#
#            0       0.58      0.64      0.61      7428
#            1       0.60      0.55      0.57      7551
#
#     accuracy                           0.59     14979
#    macro avg       0.59      0.59      0.59     14979
# weighted avg       0.59      0.59      0.59     14979

# %%
import os
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
train_path = "/content/drive/MyDrive/PetImages"
DATADIR = train_path
CATEGORIES = ["Cat", "Dog"]

# %%
from tqdm import tqdm

# %%
win_size = (64, 128)
d = cv2.HOGDescriptor()
hog = []
label = []
for i in CATEGORIES:
    path = os.path.join(train_path,i)
    class_num = CATEGORIES.index(i)
    for j in tqdm(os.listdir(path)):
        try:
            pic = cv2.imread(os.path.join(path,j))
            #show_image(pic)
            img = cv2.resize(pic, win_size)
            img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
            #fd, hog_image = hog(img, orientations=9, pixels_per_cell=(8, 8), 
                    #cells_per_block=(2, 2), visualize=True, multichannel=True)
            #fd, feature = hog(img, orientations=9, pixels_per_cell=(8, 8),cells_per_block=(2, 2), visualize=True, multichannel=False)
            feature = d.compute(img)
            feature = cv2.normalize(feature,feature)
            feature = feature.flatten()
            hog.append(feature)
            label.append(class_num)
        except Exception as e:
            pass
# Out:
# ...
# 100%|██████████| 12501/12501 [01:24<00:00, 148.61it/s]

# %%
X = np.array(hog)
y = np.array(label)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report
cluster = [3,4]
for i in cluster:
    print("The result of cluster = ", i, "is: ")
    model = KNeighborsClassifier(n_neighbors=i)
    model.fit(X_train,y_train)
    pred = model.predict(X_test)
    print(classification_report( y_test,pred))
# Out:
# The result of cluster =  3 is:
#               precision    recall  f1-score   support
#
#            0       0.75      0.30      0.43      2489
#            1       0.57      0.90      0.69      2501
#
#     accuracy                           0.60      4990
#    macro avg       0.66      0.60      0.56      4990
# weighted avg       0.66      0.60      0.56      4990
#
# The result of cluster =  4 is:
#               precision    recall  f1-score   support
#
#            0       0.72      0.43      0.54      2489
#            1       0.60      0.84      0.70      2501
#
#     accuracy                           0.63      4990
#    macro avg       0.66      0.63      0.62      4990
# weighted avg       0.66      0.63      0.62      4990
